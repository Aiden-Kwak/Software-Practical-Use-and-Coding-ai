# %%
import pandas as pd

# %%
df=pd.read_csv("D:\\ai\\Software Practical Use and Coding\\12\\pima-indians-diabetes.csv",names=["pregnant", "plasma", "pressure", "thickness","insulin", "BMI","predigree","age","class"])
#임신횟수, 혈당, 혈압, 피부두께, 인슐린, BMI, 가족력, 나이, class

# %%
df
# Out:
#      pregnant  plasma  pressure  thickness  insulin   BMI  predigree  age  \
# 0           6     148        72         35        0  33.6      0.627   50
# 1           1      85        66         29        0  26.6      0.351   31
# 2           8     183        64          0        0  23.3      0.672   32
# 3           1      89        66         23       94  28.1      0.167   21
# 4           0     137        40         35      168  43.1      2.288   33
# ..        ...     ...       ...        ...      ...   ...        ...  ...
# 763        10     101        76         48      180  32.9      0.171   63
# 764         2     122        70         27        0  36.8      0.340   27
# 765         5     121        72         23      112  26.2      0.245   30
# 766         1     126        60          0        0  30.1      0.349   47
# 767         1      93        70         31        0  30.4      0.315   23
#
#      class
# 0        1
# 1        0
# 2        1
# 3        0
# 4        1
# ...

# %%
df.head(5)
# Out:
#    pregnant  plasma  pressure  thickness  insulin   BMI  predigree  age  class
# 0         6     148        72         35        0  33.6      0.627   50      1
# 1         1      85        66         29        0  26.6      0.351   31      0
# 2         8     183        64          0        0  23.3      0.672   32      1
# 3         1      89        66         23       94  28.1      0.167   21      0
# 4         0     137        40         35      168  43.1      2.288   33      1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pregnant   768 non-null    int64
#  1   plasma     768 non-null    int64
#  2   pressure   768 non-null    int64
#  3   thickness  768 non-null    int64
#  4   insulin    768 non-null    int64
#  5   BMI        768 non-null    float64
#  6   predigree  768 non-null    float64
#  7   age        768 non-null    int64
#  8   class      768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
df.describe()
# Out:
#          pregnant      plasma    pressure   thickness     insulin         BMI  \
# count  768.000000  768.000000  768.000000  768.000000  768.000000  768.000000
# mean     3.845052  120.894531   69.105469   20.536458   79.799479   31.992578
# std      3.369578   31.972618   19.355807   15.952218  115.244002    7.884160
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      1.000000   99.000000   62.000000    0.000000    0.000000   27.300000
# 50%      3.000000  117.000000   72.000000   23.000000   30.500000   32.000000
# 75%      6.000000  140.250000   80.000000   32.000000  127.250000   36.600000
# max     17.000000  199.000000  122.000000   99.000000  846.000000   67.100000
#
#         predigree         age       class
# count  768.000000  768.000000  768.000000
# mean     0.471876   33.240885    0.348958
# std      0.331329   11.760232    0.476951
# min      0.078000   21.000000    0.000000
# 25%      0.243750   24.000000    0.000000
# ...

# %%
df[['pregnant', 'class']]
# Out:
#      pregnant  class
# 0           6      1
# 1           1      0
# 2           8      1
# 3           1      0
# 4           0      1
# ..        ...    ...
# 763        10      0
# 764         2      0
# 765         5      0
# 766         1      1
# 767         1      0
#
# [768 rows x 2 columns]

# %%
print(df[['pregnant','class']].groupby(['pregnant'], as_index=False).mean().sort_values(by='pregnant', ascending=True))
# Out:
#     pregnant     class
# 0          0  0.342342
# 1          1  0.214815
# 2          2  0.184466
# 3          3  0.360000
# 4          4  0.338235
# 5          5  0.368421
# 6          6  0.320000
# 7          7  0.555556
# 8          8  0.578947
# 9          9  0.642857
# 10        10  0.416667
# 11        11  0.636364
# 12        12  0.444444
# 13        13  0.500000
# 14        14  1.000000
# 15        15  1.000000
# 16        17  1.000000

# %%
print(df[['plasma','class']].groupby(['plasma'], as_index=False).mean().sort_values(by='plasma', ascending=True))
# Out:
#      plasma  class
# 0         0   0.40
# 1        44   0.00
# 2        56   0.00
# 3        57   0.00
# 4        61   0.00
# ..      ...    ...
# 131     195   1.00
# 132     196   1.00
# 133     197   0.75
# 134     198   1.00
# 135     199   1.00
#
# [136 rows x 2 columns]

# %% [markdown]
# <h2>데이터 상관관계_그래프 연습

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
colormap=plt.cm.gist_heat
plt.figure(figsize=(10,8))
sns.heatmap(df.corr(),linewidths=0.1,vmax=0.5, cmap=colormap, linecolor='white', annot=True)
plt.show()

# %%
plt.figure(figsize=(10,8))
plt.title('Diabetes of pima indians', fontsize=14)

# yticklabels=False 옵션을 추가해서 y측 레이블을 생략함으로 그래프가 컷트된 부분없이 모두 보임 
sns.heatmap(df.corr(), linewidths=0.2, vmax=0.5, cmap='coolwarm', linecolor='black', fmt = '.3f', annot=True, yticklabels=False)
# Out:
# <AxesSubplot:title={'center':'Diabetes of pima indians'}>

# %%
plt.figure(figsize=(10,8)) 
plt.title('Diabetes of pima indians', fontsize=14)
sns.heatmap(df.corr(),  linewidths=0.5, vmax=0.5, cmap='Blues', linecolor='white', fmt = '.2f', annot=True, yticklabels=False)
# Out:
# <AxesSubplot:title={'center':'Diabetes of pima indians'}>

# %% [markdown]
# y축 레이블이 컷트되지 않고 모두 보이면서 y축 레이블도 표현 (y축 이동을 이용한 방법)

# %%
plt.figure(figsize=(10,8)) 
plt.title('Diabetes of pima indians', fontsize=14)

#heat_4 의 현재 축을 확인
heat_4 = sns.heatmap(df.corr(), cmap='Blues', linewidths=0.5, vmax=0.5,  fmt = '.2f' , annot=True)

#heat_4 의 top 그리고 bottom 을 출력 
bottom, top = heat_4.get_ylim()
print("bottome :", bottom, "top :", top)

#heat_4 의 top 그리고 bottom 을 이동 
heat_4.set_ylim( bottom + 0.5, top - 0.5,)
# Out:
# bottome : 9.0 top : 0.0
# (9.5, -0.5)

# %% [markdown]
# 그래프를 통해 plasma 항목(공복 혈당 농도)이 0.47의 수치로 class 항목과 가장 상관관계가 높다는 것을 알 수 있음
# 즉, plasma 항목(공복 혈당 농도)이 결론을 만드는 데 가장 중요한 역할을 한다는 것을 예측할 수 있음
# 이제 plasma와 class 항목만 따로 떼어 두 항목 간의 관계를 그래프로 다시 한번 확인함

# %%
# 이미지 저장하기 
#plt.savefig('./Diabetes.png') 
#plt.show()

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.model_selection import train_test_split 

import numpy
import tensorflow as tf

# %%
seed=0
numpy.random.seed(3)
tf.random.set_seed(3)

# %% [markdown]
# 우리가 random( ) 함수를 써서 임의의 숫자를 만들어 내는 것처럼 보여도 이는 컴퓨터 안에 미리 내장된 수많은
# '랜덤 테이블’ 중 하나를 불러내 그 표의 순서대로 숫자를 보여 주는 것
# seed 값을 설정한다는 것은 그 랜덤 테이블 중에서 몇 번째 테이블을 불러와 쓸지를 정하는 것
# seed 값이 같으면 똑같은 랜덤 값을 출력함!
#
# 넘파이 라이브러리를 사용하면서 텐서플로 기반으로 딥러닝을 구현할 때는 일정한 결과값을 얻기 위해
# 넘파이 seed 값과 텐서플로 seed 값을 모두 설정해야 함
# 단, seed 값을 이렇게 지정해도 여전히 출력 값이 미세하게 다를 수 있음
# 텐서플로를 구동시키는 cuDNN 등의 내부 소프트웨어가 자체적으로 또 다른 랜덤 테이블을 생성하기 때문인데,
# 현재 이 부분의 seed 값을 지정할 방법은 없음
# 최종 딥러닝 결과는 여러 번 실행하여 평균을 구하는 것이 가장 적절함

# %%
dataset = numpy.loadtxt("D:\\ai\\Software Practical Use and Coding\\12\\pima-indians-diabetes.csv", delimiter=",")
X = dataset[:,0:8]
Y = dataset[:,8]

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, random_state=seed)

# %%
print( "학습 데이터 개수 : %d  ,  테스트 데이터 개수 %d  "  %(len(X_train), len(X_test)))
# Out:
# 학습 데이터 개수 : 537  ,  테스트 데이터 개수 231

# %%
# 모델을 설정
model = Sequential()
model.add(Dense(12, input_dim=8, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# 모델을 컴파일
model.compile(loss='binary_crossentropy', optimizer='adam',  metrics=['accuracy'])

# 모델을 실행
model.fit(X_train, Y_train, epochs=200, batch_size=10) # 학습 데이터셋 537 개로 학습
# Out:
# Train on 537 samples
# Epoch 1/200
# 537/537 [==============================] - 1s 1ms/sample - loss: 12.6868 - accuracy: 0.6257
# Epoch 2/200
# 537/537 [==============================] - 0s 73us/sample - loss: 7.8569 - accuracy: 0.5940
# Epoch 3/200
# 537/537 [==============================] - 0s 69us/sample - loss: 5.0401 - accuracy: 0.5289
# Epoch 4/200
# 537/537 [==============================] - 0s 71us/sample - loss: 3.2796 - accuracy: 0.5289
# Epoch 5/200
# 537/537 [==============================] - 0s 69us/sample - loss: 2.1857 - accuracy: 0.5251
# Epoch 6/200
# 537/537 [==============================] - 0s 69us/sample - loss: 1.4258 - accuracy: 0.5419
# Epoch 7/200
# 537/537 [==============================] - 0s 71us/sample - loss: 0.9469 - accuracy: 0.5717
# Epoch 8/200
# 537/537 [==============================] - 0s 71us/sample - loss: 0.8413 - accuracy: 0.5754
# Epoch 9/200
# 537/537 [==============================] - 0s 71us/sample - loss: 0.7967 - accuracy: 0.5791
# ...

# %%
# 30%에 해당하는 231개의 테스트 데이터셋으로 정확도 계산 결과를 출력
print("\n Test Accuracy : %.4f" % (model.evaluate(X_test, Y_test)[1]))
# Out:
# 231/1 [===============================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================
# ...

# %%
from keras.models import load_model

model.save('Diabetes of Pima Indians_deep_learning_result_save.h5')
# Out:
# Using TensorFlow backend.

# %%
import numpy as np
kim = np.array([[3, 78, 50, 32, 88, 31, 0.248, 26]])
park = np.array([[10, 115, 0, 0, 0, 35.3, 0.134, 29]])
choi = np.array([[2, 197, 70, 45, 543, 30.5, 0.158, 53]])

test_kim  = model.predict(kim)*100
test_park = model.predict(park)*100
test_choi = model.predict(choi)*100
print("Kim  당뇨병 가능성 예측 : %.2f" %test_kim, "%")
print("Park 당뇨병 가능성 예측 : %.2f" %test_park, "%")
print("Choi 당뇨병 가능성 예측 : %.2f" %test_choi, "%")
# Out:
# Kim  당뇨병 가능성 예측 : 24.17 %
# Park 당뇨병 가능성 예측 : 42.33 %
# Choi 당뇨병 가능성 예측 : 99.31 %
